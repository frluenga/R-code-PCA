# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\GAMER\\Documents\\Estadistica\\Multivariado'

# %%
# df_2019 = pd.read_csv("C:\\Users\\GAMER\\Documents\\Estadistica\\Bases_de_datos\\2019.csv",sep=",")
# df_2018 = pd.read_csv("C:\\Users\\GAMER\\Documents\\Estadistica\\Bases_de_datos\\2018.csv",sep=",")
# df_2017 = pd.read_csv("C:\\Users\\GAMER\\Documents\\Estadistica\\Bases_de_datos\\2017.csv",sep=",")
# df_2016 = pd.read_csv("C:\\Users\\GAMER\\Documents\\Estadistica\\Bases_de_datos\\2016.csv",sep=",")
# df_2015 = pd.read_csv("C:\\Users\\GAMER\\Documents\\Estadistica\\Bases_de_datos\\2015.csv",sep=",")

# %%
# df_2019.info()
# df_2019
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# ...

# %%
# df_2019['year'] = 2019
# df_2018['year'] = 2018
# df_2017['year'] = 2017
# df_2016['year'] = 2016
# df_2015['year'] = 2015

# %%
# df_2019 = df_2019.set_index(['Country or region']).sort_index()
# df_2018 = df_2018.set_index(['Country or region']).sort_index()
# df_2017 = df_2017.set_index(['Country']).sort_index()
# df_2016 = df_2016.set_index(['Country']).sort_index()
# df_2015 = df_2015.set_index(['Country']).sort_index()

# df_2019 = df_2019.drop(['Overall rank'],axis=1)
# df_2018 = df_2018.drop(['Overall rank'],axis=1)
# df_2017 = df_2017.drop(['Happiness.Rank'],axis=1)
# df_2016 = df_2016.drop(['Happiness Rank'],axis=1)
# df_2015 = df_2015.drop(['Happiness Rank'],axis=1)

# df_2018 = df_2018.drop(['Whisker.high','Dystopia.Residual'],axis=1)
# df_2016 = df_2016.drop(['Region','Lower Confidence Interval','Upper Confidence Interval','Dystopia Residual'],axis=1)
# df_2017 = df_2017.drop(['Whisker.high','Whisker.low','Dystopia.Residual'],axis=1)
# df_2015 = df_2015.drop(['Region','Standard Error','Dystopia Residual'],axis=1)


# df_2019 = df_2019.reset_index()
# df_2018 = df_2018.reset_index()
# df_2017 = df_2017.reset_index()
# df_2016 = df_2016.reset_index()
# df_2015 = df_2015.reset_index()

# df_2019 = df_2019.rename(columns={'Country or region':'Country',
#                                   'Score':'Score',
#                                   'GDP per capita':'GDP.per.capita',
#                                   'Social support':'Social.support',
#                                   'Healthy life expectancy':'Healthy.life.expectancy',
#                                   'Freedom to make life choices':'Freedom.to.make.choices',
#                                   'Generosity':'Generosity',
#                                   'Perceptions of corruption':'Perceptions.corruption',
#                                   'year':'year'})

# df_2018 = df_2018.rename(columns={'Country or region':'Country',
#                                   'Score':'Score',
#                                   'GDP per capita':'GDP.per.capita',
#                                   'Social support':'Social.support',
#                                   'Healthy life expectancy':'Healthy.life.expectancy',
#                                   'Freedom to make life choices':'Freedom.to.make.choices',
#                                   'Generosity':'Generosity',
#                                   'Perceptions of corruption':'Perceptions.corruption',
#                                   'year':'year'})

# df_2017 = df_2017.rename(columns={'Country':'Country',
#                                   'Happiness.Score':'Score',
#                                   'Economy..GDP.per.Capita.':'GDP.per.capita',
#                                   'Family':'Social.support',
#                                   'Health..Life.Expectancy.':'Healthy.life.expectancy',
#                                   'Freedom':'Freedom.to.make.choices',
#                                   'Generosity':'Generosity',
#                                   'Trust..Government.Corruption.':'Perceptions.corruption',
#                                   'year':'year'})

# df_2016 = df_2016.rename(columns={'Country':'Country',
#                                   'Happiness Score':'Score',
#                                   'Economy (GDP per Capita)':'GDP.per.capita',
#                                   'Family':'Social.support',
#                                   'Health (Life Expectancy)':'Healthy.life.expectancy',
#                                   'Freedom':'Freedom.to.make.choices',
#                                   'Generosity':'Generosity',
#                                   'Trust (Government Corruption)':'Perceptions.corruption',
#                                   'year':'year'})

# df_2015 = df_2015.rename(columns={'Country':'Country',
#                                   'Happiness Score':'Score',
#                                   'Economy (GDP per Capita)':'GDP.per.capita',
#                                   'Family':'Social.support',
#                                   'Health (Life Expectancy)':'Healthy.life.expectancy',
#                                   'Freedom':'Freedom.to.make.choices',
#                                   'Generosity':'Generosity',
#                                   'Trust (Government Corruption)':'Perceptions.corruption',
#                                   'year':'year'})

# df_2018
# Out:
#          Country  Score  GDP.per.capita  Social.support  \
# 0    Afghanistan  3.632           0.332           0.537
# 1        Albania  4.586           0.916           0.817
# 2        Algeria  5.295           0.979           1.154
# 3         Angola  3.795           0.730           1.125
# 4      Argentina  6.388           1.073           1.468
# ..           ...    ...             ...             ...
# 151    Venezuela  4.806           0.996           1.469
# 152      Vietnam  5.103           0.715           1.365
# 153        Yemen  3.355           0.442           1.073
# 154       Zambia  4.377           0.562           1.047
# 155     Zimbabwe  3.692           0.357           1.094
#
#      Healthy.life.expectancy  Freedom.to.make.choices  Generosity  \
# 0                      0.255                    0.085       0.191
# 1                      0.790                    0.419       0.149
# 2                      0.687                    0.077       0.055
# ...

# %%
df = pd.concat([df_2019,df_2018,df_2017,df_2016,df_2015]).sort_index()

# %%
# df = df.reset_index()
df = df.set_index(['Country']).sort_index()

# %%
df_final = df.drop(['Country'],axis=1)

# %%
df_final
# Out:
#      Score  GDP.per.capita  Social.support  Healthy.life.expectancy  \
# 0    3.203        0.350000        0.517000                 0.361000
# 1    3.794        0.401477        0.581543                 0.180747
# 2    3.575        0.319820        0.302850                 0.303350
# 3    3.632        0.332000        0.537000                 0.255000
# 4    3.360        0.382270        0.110370                 0.173440
# ..     ...             ...             ...                      ...
# 777  3.663        0.366000        1.114000                 0.433000
# 778  3.875        0.375847        1.083096                 0.196764
# 779  3.692        0.357000        1.094000                 0.248000
# 780  4.193        0.350410        0.714780                 0.159500
# 781  4.610        0.271000        1.032760                 0.334750
#
#      Freedom.to.make.choices  Generosity  Perceptions.corruption  year
# 0                   0.000000    0.158000                0.025000  2019
# ...

# %%
dir_pandas = 'C:\\Users\\GAMER\\Documents\\Estadistica\\Multivariado{}'.format('DataSet2.csv')

# %%
df.to_csv(dir_pandas, sep = ',', index = False)

# %%
df = df.reset_index()

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# index                      0
# Country                    0
# Score                      0
# GDP.per.capita             0
# Social.support             0
# Healthy.life.expectancy    0
# Freedom.to.make.choices    0
# Generosity                 0
# Perceptions.corruption     0
# year                       0
# dtype: int64
